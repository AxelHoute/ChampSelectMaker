# %%
import pandas as pd
import requests
import time

# %% [markdown]
# [DIAMOND,EMERALD,PLATINUM,GOLD,SILVER,BRONZE,IRON]

# %%
api_key = ['RGAPI-8f453b47-e309-4c70-8a22-ae0ad2d5f505','RGAPI-af854422-4c5b-467e-8a51-a104ef627259']

def fetch(json,match,feature,feature_chall,feature_teams):
    try :
        if json["info"]['queueId']==420 :
            data=[]
            for k in range(len(json['metadata']["participants"])) :
                
                data+=[json['metadata']["matchId"]]

                data+=[[json['info']["teams"][0]["bans"][k]["championId"] for k in range(5)] + [json['info']["teams"][1]["bans"][k]["championId"] for k in range(5)]]
                if k>5:
                    for feat in feature_teams :
                        data+=[json['info']["teams"][1][feat]]

                else : 
                    for feat in feature_teams :
                        data+=[json['info']["teams"][0][feat]]

                for feat_chall in feature_chall :
                    data+=[json['info']["participants"][k]["challenges"][feat_chall]]
                    

                for feat in feature :
                    data+=[json['info']["participants"][k][feat]]

                match+=[data]
                data=[]
    except Exception as e:
        print(f"Une erreur est survenue : {e}")
    return match

def getgame(elo,api_key): 

    headers = [{
        "X-Riot-Token": api_key[0]
    },{
        "X-Riot-Token": api_key[1]
    }]
    region = 'euw1'
    request=0
    joueurs=[]
    for div in ["I","II","III","IV","V"] : 
        url = f"https://euw1.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/{elo}/{div}"
        for k in range(1,4):
            joueurs += requests.get(url+f"?page={k}", headers=headers[0]).json()
            request+=1
    
    games=[]

    for joueur in joueurs :
        if request<99 :
            try :
                games+=requests.get(f'https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/{joueur["puuid"]}/ids?start=0&count=15',headers=headers[0]).json()
                request+=1
            except :
                print("error")

        elif request==99 and request_<99: 
            try :
                games+=requests.get(f'https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/{joueur["puuid"]}/ids?start=0&count=15',headers=headers[1]).json()
                request_+=1
            except :
                print("error")
        else :
            time.sleep(120)
            request=0  
            request_=0  

    pd.DataFrame(columns=["gameId"],data=games).to_csv(f"gamesID_{elo}.csv", index=False)
    return games


def getmatchs(games,api_key):
    headers = [{
        "X-Riot-Token": api_key[0]
    },{
        "X-Riot-Token": api_key[1]
    }]

    region = 'euw1'
    feature=['puuid','championId',"deaths","kills","damageDealtToObjectives","damageDealtToBuildings","magicDamageDealt","magicDamageTaken","physicalDamageDealt","physicalDamageTaken",
             "timeCCingOthers","totalDamageShieldedOnTeammates","totalHeal","goldSpent","goldEarned","totalEnemyJungleMinionsKilled","totalAllyJungleMinionsKilled","lane","killingSprees","totalMinionsKilled"]
    
    feature_chall=["kda","killParticipation","goldPerMinute","damagePerMinute","soloKills","skillshotsDodged","skillshotsHit","visionScorePerMinute"]
    feature_teams=["teamId","win"]

    matchs=[]

    print(len(games))
    request=0
    request_=99
    for x in games:
        if request<99 :
            try :
                matchs= fetch(requests.get(f'https://europe.api.riotgames.com/lol/match/v5/matches/{x}',headers=headers[0]).json(),matchs,feature,feature_chall,feature_teams)
                request+=1
            except :
                print(requests.get(f'https://europe.api.riotgames.com/lol/match/v5/matches/{x}',headers=headers[0]).json())
                request+=1

        elif request==99 and request_<99: 
            try :
                matchs= fetch(requests.get(f'https://europe.api.riotgames.com/lol/match/v5/matches/{x}',headers=headers[1]).json(),matchs,feature,feature_chall,feature_teams)
                request_+=1
            except :
                print(requests.get(f'https://europe.api.riotgames.com/lol/match/v5/matches/{x}',headers=headers[1]).json())
                request_+=1
        else :
            time.sleep(120)
            request=0  
            request_=0             

    return pd.DataFrame(data=matchs,columns=["matchId","bans"]+feature_teams+feature_chall+feature)

# %%
games = getgame("PLATINUM",api_key)
# Out:
# error
# error
# error

# %%
games = pd.read_csv("gamesID_PLATINUM.csv")["gameId"].values.tolist()

# %%
import os
elo = "DIAMOND"
file_path = f"gamesID_{elo}.csv"
os.path.exists(file_path)
# Out:
# True

# %%
matches = getmatchs(games,api_key)
# Out:
# 36882
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'
# Une erreur est survenue : 'killParticipation'

# %%
matches
# Out:
#                 matchId                                          bans  teamId  \
# 0       EUW1_7307552867  [81, 56, 83, 28, 800, 350, 40, 117, 82, 112]     100
# 1       EUW1_7307552867  [81, 56, 83, 28, 800, 350, 40, 117, 82, 112]     100
# 2       EUW1_7307552867  [81, 56, 83, 28, 800, 350, 40, 117, 82, 112]     100
# 3       EUW1_7307552867  [81, 56, 83, 28, 800, 350, 40, 117, 82, 112]     100
# 4       EUW1_7307552867  [81, 56, 83, 28, 800, 350, 40, 117, 82, 112]     100
# ...                 ...                                           ...     ...
# 220370  EUW1_7269880697   [51, 111, 19, 28, 711, 62, 555, 25, 82, -1]     100
# 220371  EUW1_7269880697   [51, 111, 19, 28, 711, 62, 555, 25, 82, -1]     200
# 220372  EUW1_7269880697   [51, 111, 19, 28, 711, 62, 555, 25, 82, -1]     200
# 220373  EUW1_7269880697   [51, 111, 19, 28, 711, 62, 555, 25, 82, -1]     200
# 220374  EUW1_7269880697   [51, 111, 19, 28, 711, 62, 555, 25, 82, -1]     200
#
#           win       kda  killParticipation  goldPerMinute  damagePerMinute  \
# 0       False  1.285714           0.562500     366.490548       795.600731
# 1       False  1.200000           0.375000     312.655111       156.457063
# 2       False  2.666667           0.500000     401.543168       681.093465
# 3       False  1.800000           0.562500     376.775597       602.137184
# 4       False  3.666667           0.687500     252.225865       465.495884
# ...       ...       ...                ...            ...              ...
# 220370   True  0.666667           0.333333     322.576873       558.709962
# 220371  False  0.750000           0.500000     339.571778       327.590238
# 220372  False  0.100000           0.083333     294.187581       585.198781
# 220373  False  1.000000           0.500000     340.851550       463.911171
# 220374  False  1.000000           0.500000     257.163380       567.927309
#
#         soloKills  skillshotsDodged  ...  timeCCingOthers  \
# 0               1                15  ...               68
# 1               0                 5  ...                9
# 2               1                20  ...                1
# 3               0                13  ...               16
# 4               0                15  ...               16
# ...           ...               ...  ...              ...
# 220370          0                20  ...               25
# 220371          2                53  ...              102
# 220372          1                22  ...               18
# 220373          0                51  ...                4
# 220374          1                50  ...               30
#
#         totalDamageShieldedOnTeammates totalHeal  goldSpent  goldEarned  \
# 0                                    0      6393      10400       10574
# 1                                    0     12508       9075        9021
# 2                                    0      3958       9975       11586
# 3                                    0      3911      10600       10871
# 4                                 3616      7929       6850        7277
# ...                                ...       ...        ...         ...
# 220370                               0      1675       7275        7417
# 220371                               0     10818       6800        7808
# 220372                               0       427       6800        6765
# 220373                               0      1720       7250        7838
# 220374                               0       769       5150        5913
#
#         totalEnemyJungleMinionsKilled  totalAllyJungleMinionsKilled    lane  \
# 0                                   0                             0     TOP
# 1                                   0                             0  JUNGLE
# 2                                   0                             0     TOP
# 3                                   0                             0  BOTTOM
# 4                                   0                             0  BOTTOM
# ...                               ...                           ...     ...
# 220370                              0                             0     TOP
# 220371                              0                             0  JUNGLE
# 220372                              0                             0  MIDDLE
# 220373                              0                             0  BOTTOM
# 220374                              0                             0  MIDDLE
#
#         killingSprees  totalMinionsKilled
# 0                   1                 186
# 1                   0                  11
# 2                   1                 239
# 3                   2                 212
# 4                   0                  32
# ...               ...                 ...
# 220370              1                 147
# 220371              1                  34
# 220372              0                 155
# 220373              1                 151
# 220374              1                  40
#
# [220375 rows x 32 columns]

# %%
matches["elo"]="PLATINUM"

# %%
matches["matchId"].unique()
# Out:
# array(['EUW1_7307552867', 'EUW1_7307538859', 'EUW1_7307494734', ...,
#        'EUW1_7270270093', 'EUW1_7270092138', 'EUW1_7269880697'],
#       dtype=object)

# %%
matches.to_csv(f"matchesID_PLATINUM.csv", index=False)

# %%
for col in ["matchId","bans","puuid","lane","elo"]:  # Seulement les colonnes texte
    matches[col] = matches[col].astype(str)  # Convertir en string pour éviter les objets
    matches[col] = matches[col].apply(lambda x: x.encode("utf-8", "ignore").decode("utf-8") if isinstance(x, str) else x)

# %%
from sqlalchemy import create_engine
import json
with open('server.json', 'r', encoding='utf-8') as fichier :
    donnees = json.load(fichier)
# ⚡ Connexion à PostgreSQL
USER = donnees["USER"]
PASSWORD = donnees["PASSWORD"]
HOST = "localhost"  # ou une adresse IP distante
PORT = "5432"
DB_NAME = "Champ_selectbdd"

# Créer une connexion SQLAlchemy
engine = create_engine(f"postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB_NAME}")
try:
    # Essayer de se connecter
    with engine.connect() as connection:
        print("✅ Connexion réussie à la base de données via SQLAlchemy !")
except Exception as e:
    print(f"❌ Erreur de connexion : {e}")
# ⚡ Insérer le DataFrame dans la table "ma_table"

matches.to_sql("Matchs", engine, if_exists="append", index=False)
# Out:
# ✅ Connexion réussie à la base de données via SQLAlchemy !
# 595

# %%
matches["matchId"].astype(str)
# Out:
# 0         EUW1_7307552867
# 1         EUW1_7307552867
# 2         EUW1_7307552867
# 3         EUW1_7307552867
# 4         EUW1_7307552867
#                ...
# 220370    EUW1_7269880697
# 220371    EUW1_7269880697
# 220372    EUW1_7269880697
# 220373    EUW1_7269880697
# 220374    EUW1_7269880697
# Name: matchId, Length: 220375, dtype: object

# %%
print(matches.dtypes)
# Out:
# matchId                            object
# bans                               object
# teamId                              int64
# win                                  bool
# kda                               float64
# killParticipation                 float64
# goldPerMinute                     float64
# damagePerMinute                   float64
# soloKills                           int64
# skillshotsDodged                    int64
# skillshotsHit                       int64
# visionScorePerMinute              float64
# puuid                              object
# championId                          int64
# deaths                              int64
# kills                               int64
# damageDealtToObjectives             int64
# damageDealtToBuildings              int64
# magicDamageDealt                    int64
# magicDamageTaken                    int64
# physicalDamageDealt                 int64
# physicalDamageTaken                 int64
# timeCCingOthers                     int64
# totalDamageShieldedOnTeammates      int64
# totalHeal                           int64
# goldSpent                           int64
# goldEarned                          int64
# totalEnemyJungleMinionsKilled       int64
# totalAllyJungleMinionsKilled        int64
# lane                               object
# killingSprees                       int64
# totalMinionsKilled                  int64
# elo                                object
# dtype: object

# %%
url = f"https://europe.api.riotgames.com/lol/match/v5/matches/EUW1_7318414088"
headers = {
        "X-Riot-Token": 'RGAPI-687c461e-3a20-4c87-a6cd-b9c50a8f2829'
    }
requests.get(url,headers=headers).json()
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'EUW1_7318414088',
#   'participants': ['jkoISeqpqCy5cr_NnNcuDjWKuXAQp5VmaoPxYwYRAwNuBHzivMXqMAzq61bNdKcutjzSyYTGBfr2XQ',
#    'vC8U3YssS09y0Q2oDMOMAFDuVpKz91Y7Jq8fcHSExmWZzyx2Wga4WKRhDZ3PFSXBzzdAdcAp13iJkg',
#    'AxqPWjgu5IfG-7F21wr9J7sqboB-XWD4lC2JPFEht4OfahbXnD5qQev8CEyAw9c5baLT0-ejzhHHwQ',
#    'kcRbS0LHO3W7NvW9IDQdmn2J9Pkccq9o7EPjxBRRl5GDhobC_SHe-f7PHPLIbe6CFuqbn-MLFY9m1A',
#    'VA4mQgVmV3DBf-2vHY-vOypZYbIFn8cuP9Bjt5MBim0WCmdre-mW9n-xtmmwjXID7z2VQ9V1UMPRbw',
#    'LmPYUMosWcaNfSWBiwVKh7LTppkkzJ6Su6deDVpOOAKBBkOIQ7vMFkipMV_HwfB0cOLCOx_VPci6zQ',
#    'fPb9xlEKg2sDx_pQUMWOkjky_fF0srNLBOHkS2066zwUCd7YEg6Xr61oYI0uDPUfubkDu2tq8RIv6g',
#    '4ycJ5r__VxSIi969mjevMLROrVHsT5Lxj4qCGwJigzA0JADCHLl_57wDWeLvZxXcfKz6LrTa72b1Bg',
#    '8eYOTbrevqzIP2Ac0SG2vFZQu5t7IxUf_CXMGe7gQSMWRD1y464NhsnEMOuz96vbZAF7xCTzHhBoyA',
#    'xeOSP_aJDyNWwNqNfQddm921jQXymaz19RI1cvR-ww3zHREhylgsV_BAldZDd5rWh_GtXFTNPXereA']},
#  'info': {'endOfGameResult': 'GameComplete',
#   'gameCreation': 1740457716971,
#   'gameDuration': 843,
#   'gameEndTimestamp': 1740458587002,
#   'gameId': 7318414088,
#   'gameMode': 'ARAM',
#   'gameName': 'teambuilder-match-7318414088',
#   'gameStartTimestamp': 1740457743069,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '15.4.657.5386',
#   'mapId': 12,
#   'participants': [{'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 24,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 4,
#     'challenges': {'12AssistStreakCount': 1,
#      'HealFromMapSources': 581.0098533630371,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 141,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 958.140401329367,
#      'damageTakenOnTeamPercentage': 0.24230706226250748,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 818.6469116210938,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 27,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 507.673493505,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 11,
#      'gameLength': 844.222486342,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 651.1171904686958,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 11,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 3,
#      'kda': 7,
#      'killAfterHiddenWithAlly': 6,
#      'killParticipation': 0.8235294117647058,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 14,
#      'laneMinionsFirst10Minutes': 24,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [2503, 6653],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 0,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 17,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 1,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 1,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 12,
#      'skillshotsHit': 25,
#      'snowballsHit': 6,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 28,
#      'takedownsAfterGainingLevelAdvantage': 2,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 28,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.204935485605926,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 11547,
#     'champLevel': 14,
#     'championId': 25,
#     'championName': 'Morgana',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 1318,
#     'damageDealtToObjectives': 1318,
#     'damageDealtToTurrets': 1318,
#     'damageSelfMitigated': 5921,
#     'dangerPings': 0,
#     'deaths': 4,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': True,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 9161,
#     'goldSpent': 8500,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 2503,
#     'item1': 2420,
#     'item2': 6653,
#     'item3': 3020,
#     'item4': 0,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 7,
#     'killingSprees': 1,
#     'kills': 4,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 238,
#     'magicDamageDealt': 26929,
#     'magicDamageDealtToChampions': 12165,
#     'magicDamageTaken': 6588,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 906, 'var2': 20, 'var3': 0},
#         {'perk': 8126, 'var1': 551, 'var2': 0, 'var3': 0},
#         {'perk': 8140, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 4, 'var2': 26, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8009, 'var1': 3456, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 311, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 3271,
#     'physicalDamageDealtToChampions': 377,
#     'physicalDamageTaken': 4874,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 654,
#     'pushPings': 0,
#     'puuid': 'jkoISeqpqCy5cr_NnNcuDjWKuXAQp5VmaoPxYwYRAwNuBHzivMXqMAzq61bNdKcutjzSyYTGBfr2XQ',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': 'LGBT Juanky',
#     'riotIdTagline': 'EUW',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 52,
#     'spell2Casts': 63,
#     'spell3Casts': 19,
#     'spell4Casts': 7,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 13,
#     'summoner2Id': 32,
#     'summonerId': 'XHUHtfw2KA8G9LwjJtUxcLhQUyeaQfXUKPVzOEa2TK3Sw-Y',
#     'summonerLevel': 882,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 56,
#     'timePlayed': 843,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 31209,
#     'totalDamageDealtToChampions': 13481,
#     'totalDamageShieldedOnTeammates': 818,
#     'totalDamageTaken': 12165,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 2503,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 28,
#     'totalTimeCCDealt': 75,
#     'totalTimeSpentDead': 97,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1007,
#     'trueDamageDealtToChampions': 938,
#     'trueDamageTaken': 702,
#     'turretKills': 0,
#     'turretTakedowns': 3,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 31,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 2,
#      'HealFromMapSources': 223.24538612365723,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 146,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 374.3281600674869,
#      'damageTakenOnTeamPercentage': 0.176184553248485,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 3,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 11346.30078125,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 38,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 507.673493505,
#      'fistBumpParticipation': 1,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 11,
#      'gameLength': 844.222486342,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 625.0603929646211,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 7,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 4,
#      'kda': 10.333333333333334,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.9117647058823529,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 7,
#      'landSkillShotsEarlyGame': 8,
#      'laneMinionsFirst10Minutes': 5,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6617, 3107, 6621],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 0,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 21,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 1,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 24,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 6,
#      'skillshotsHit': 18,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 31,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 31,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.08006459507705552,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 12135,
#     'champLevel': 14,
#     'championId': 902,
#     'championName': 'Milio',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 1327,
#     'damageDealtToObjectives': 1327,
#     'damageDealtToTurrets': 1327,
#     'damageSelfMitigated': 3443,
#     'dangerPings': 0,
#     'deaths': 3,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 2,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': True,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 8794,
#     'goldSpent': 7900,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3158,
#     'item1': 6617,
#     'item2': 3107,
#     'item3': 6621,
#     'item4': 0,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 7,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 287,
#     'magicDamageDealt': 17115,
#     'magicDamageDealtToChampions': 4805,
#     'magicDamageTaken': 4946,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 576, 'var2': 1281, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 91, 'var3': 0},
#         {'perk': 8210, 'var1': 25, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 261, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 276, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 2740, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 1852,
#     'physicalDamageDealtToChampions': 312,
#     'physicalDamageTaken': 2546,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4561,
#     'pushPings': 0,
#     'puuid': 'vC8U3YssS09y0Q2oDMOMAFDuVpKz91Y7Jq8fcHSExmWZzyx2Wga4WKRhDZ3PFSXBzzdAdcAp13iJkg',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': 'BOOM SHAKA LAKA8',
#     'riotIdTagline': 'EUW',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 58,
#     'spell2Casts': 26,
#     'spell3Casts': 58,
#     'spell4Casts': 4,
#     'subteamPlacement': 0,
#     'summoner1Casts': 2,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 3,
#     'summonerId': 'VvFWXB6uAZr5W2Fok1APeIYzCT1lDcx7qVUpozNE4Efm7ywi',
#     'summonerLevel': 834,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 18,
#     'timePlayed': 843,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 19117,
#     'totalDamageDealtToChampions': 5266,
#     'totalDamageShieldedOnTeammates': 5255,
#     'totalDamageTaken': 8845,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 7738,
#     'totalHealsOnTeammates': 6091,
#     'totalMinionsKilled': 7,
#     'totalTimeCCDealt': 241,
#     'totalTimeSpentDead': 67,
#     'totalUnitsHealed': 6,
#     'tripleKills': 0,
#     'trueDamageDealt': 149,
#     'trueDamageDealtToChampions': 149,
#     'trueDamageTaken': 1352,
#     'turretKills': 0,
#     'turretTakedowns': 4,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 9,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 14,
#     'challenges': {'12AssistStreakCount': 0,
#      'HealFromMapSources': 337.3396053314209,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 87,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1061.4152079982573,
#      'damageTakenOnTeamPercentage': 0.15863662333532777,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 2,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 384,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 17,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'fastestLegendary': 686.8357079650001,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 507.673493505,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 11,
#      'gameLength': 844.222486342,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 796.276806211394,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 6,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 3,
#      'kda': 11.5,
#      'killAfterHiddenWithAlly': 10,
#      'killParticipation': 0.6764705882352942,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 3,
#      'killsNearEnemyTurret': 8,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 1,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 16,
#      'laneMinionsFirst10Minutes': 36,
#      'legendaryCount': 1,
#      'legendaryItemUsed': [6676, 3031, 3094],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 0,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 17,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 1,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 14,
#      'skillshotsHit': 22,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 23,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 23,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 2,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.22702480845065978,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 11876,
#     'champLevel': 14,
#     'championId': 51,
#     'championName': 'Caitlyn',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 2968,
#     'damageDealtToObjectives': 2968,
#     'damageDealtToTurrets': 2968,
#     'damageSelfMitigated': 4160,
#     'dangerPings': 0,
#     'deaths': 2,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11203,
#     'goldSpent': 9500,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6676,
#     'item1': 1001,
#     'item2': 3031,
#     'item3': 3094,
#     'item4': 0,
#     'item5': 0,
#     'item6': 0,
#     'itemsPurchased': 10,
#     'killingSprees': 3,
#     'kills': 14,
#     'lane': 'NONE',
#     'largestCriticalStrike': 1048,
#     'largestKillingSpree': 8,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 432,
#     'magicDamageDealt': 945,
#     'magicDamageDealtToChampions': 673,
#     'magicDamageTaken': 4341,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 239, 'var2': 239, 'var3': 0},
#         {'perk': 8009, 'var1': 1710, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 7, 'var2': 40, 'var3': 0},
#         {'perk': 8014, 'var1': 499, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 668, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 320, 'var2': 4, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 42341,
#     'physicalDamageDealtToChampions': 14158,
#     'physicalDamageTaken': 3269,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4655,
#     'pushPings': 0,
#     'puuid': 'AxqPWjgu5IfG-7F21wr9J7sqboB-XWD4lC2JPFEht4OfahbXnD5qQev8CEyAw9c5baLT0-ejzhHHwQ',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': '布响丸辣',
#     'riotIdTagline': '馨馨子',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 31,
#     'spell2Casts': 37,
#     'spell3Casts': 14,
#     'spell4Casts': 5,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 4,
#     'summoner2Id': 7,
#     'summonerId': 's8azWXr4ehgz5NUO2MnB8ELUbXyDCsFNba7nLuPGHVzvVpuh',
#     'summonerLevel': 413,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 25,
#     'timePlayed': 843,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 43422,
#     'totalDamageDealtToChampions': 14934,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 7964,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 2719,
#     'totalHealsOnTeammates': 384,
#     'totalMinionsKilled': 45,
#     'totalTimeCCDealt': 101,
#     'totalTimeSpentDead': 45,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 135,
#     'trueDamageDealtToChampions': 102,
#     'trueDamageTaken': 353,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 12,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 12,
#     'challenges': {'12AssistStreakCount': 0,
#      'HealFromMapSources': 738.0880632400513,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 175,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 102.5,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1196.8191062292883,
#      'damageTakenOnTeamPercentage': 0.23408776598548445,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 3,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 233.5140838623047,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 13,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 507.673493505,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 11,
#      'gameLength': 844.222486342,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 767.4382331232837,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 4,
#      'kda': 6,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.7058823529411765,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 9,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 1,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 18,
#      'laneMinionsFirst10Minutes': 13,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [4646, 6655, 4645],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 0,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 16,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 1,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 18,
#      'skillshotsHit': 38,
#      'snowballsHit': 3,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 24,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 24,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 1,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.25598618362950765,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 11648,
#     'champLevel': 14,
#     'championId': 142,
#     'championName': 'Zoe',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 2372,
#     'damageDealtToObjectives': 2372,
#     'damageDealtToTurrets': 2372,
#     'damageSelfMitigated': 4578,
#     'dangerPings': 0,
#     'deaths': 4,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': True,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 10798,
#     'goldSpent': 10600,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6655,
#     'item1': 3020,
#     'item2': 4646,
#     'item3': 4645,
#     'item4': 1052,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 13,
#     'killingSprees': 2,
#     'kills': 12,
#     'lane': 'NONE',
#     'largestCriticalStrike': 181,
#     'largestKillingSpree': 7,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 334,
#     'magicDamageDealt': 21032,
#     'magicDamageDealtToChampions': 13502,
#     'magicDamageTaken': 4622,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 1322, 'var2': 21, 'var3': 0},
#         {'perk': 8139, 'var1': 801, 'var2': 0, 'var3': 0},
#         {'perk': 8140, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 608, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 2327, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 4435,
#     'physicalDamageDealtToChampions': 1054,
#     'physicalDamageTaken': 2898,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6300,
#     'pushPings': 0,
#     'puuid': 'kcRbS0LHO3W7NvW9IDQdmn2J9Pkccq9o7EPjxBRRl5GDhobC_SHe-f7PHPLIbe6CFuqbn-MLFY9m1A',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': 'uOvOn',
#     'riotIdTagline': '0007',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 91,
#     'spell2Casts': 25,
#     'spell3Casts': 32,
#     'spell4Casts': 27,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 14,
#     'summonerId': 'Sydl0Q5Zr7aYM1Yt-NVTiJ6gZQ_YrBxnGh5gyR5i8kuQRKsBP-8QjCqZPA',
#     'summonerLevel': 421,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 22,
#     'timePlayed': 843,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 27751,
#     'totalDamageDealtToChampions': 16839,
#     'totalDamageShieldedOnTeammates': 233,
#     'totalDamageTaken': 11753,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1508,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 16,
#     'totalTimeCCDealt': 74,
#     'totalTimeSpentDead': 73,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2283,
#     'trueDamageDealtToChampions': 2283,
#     'trueDamageTaken': 4232,
#     'turretKills': 2,
#     'turretTakedowns': 4,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 22,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 4,
#     'challenges': {'12AssistStreakCount': 1,
#      'HealFromMapSources': 539.8157358169556,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 178,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1084.6240864020394,
#      'damageTakenOnTeamPercentage': 0.1887839951681953,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 7,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 507.673493505,
#      'fistBumpParticipation': 1,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 11,
#      'gameLength': 844.222486342,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 674.7399343367395,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 3,
#      'kda': 6.5,
#      'killAfterHiddenWithAlly': 8,
#      'killParticipation': 0.7647058823529411,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 37,
#      'laneMinionsFirst10Minutes': 35,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [2503, 3100],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 0,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 18,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 7,
#      'skillshotsHit': 73,
#      'snowballsHit': 6,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 26,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 26,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.23198892723685105,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 11773,
#     'champLevel': 14,
#     'championId': 112,
#     'championName': 'Viktor',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 1273,
#     'damageDealtToObjectives': 1273,
#     'damageDealtToTurrets': 1273,
#     'damageSelfMitigated': 5552,
#     'dangerPings': 0,
#     'deaths': 4,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 4,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 1,
#     'goldEarned': 9493,
#     'goldSpent': 8450,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 2503,
#     'item1': 2031,
#     'item2': 3020,
#     'item3': 3100,
#     'item4': 1058,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 8,
#     'killingSprees': 1,
#     'kills': 4,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 381,
#     'magicDamageDealt': 37864,
#     'magicDamageDealtToChampions': 14505,
#     'magicDamageTaken': 5164,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8229, 'var1': 1284, 'var2': 0, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 584, 'var3': 0},
#         {'perk': 8210, 'var1': 11, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 505, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 330, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 3644, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 3624,
#     'physicalDamageDealtToChampions': 450,
#     'physicalDamageTaken': 3979,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3221,
#     'pushPings': 0,
#     'puuid': 'VA4mQgVmV3DBf-2vHY-vOypZYbIFn8cuP9Bjt5MBim0WCmdre-mW9n-xtmmwjXID7z2VQ9V1UMPRbw',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': '强者从不回忆往昔一心只想增肌',
#     'riotIdTagline': '8850',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 46,
#     'spell2Casts': 31,
#     'spell3Casts': 60,
#     'spell4Casts': 41,
#     'subteamPlacement': 0,
#     'summoner1Casts': 15,
#     'summoner1Id': 32,
#     'summoner2Casts': 1,
#     'summoner2Id': 4,
#     'summonerId': 'cDO-fSmx4WJw_Ol9WLz5ht7nKsM1Ps2O-raNEBM33T1ZQkE',
#     'summonerLevel': 437,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 20,
#     'timePlayed': 843,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 41793,
#     'totalDamageDealtToChampions': 15261,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 9478,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 537,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 45,
#     'totalTimeCCDealt': 502,
#     'totalTimeSpentDead': 81,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 305,
#     'trueDamageDealtToChampions': 305,
#     'trueDamageTaken': 333,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 0,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': True},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 10,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 3,
#     'challenges': {'12AssistStreakCount': 0,
#      'HealFromMapSources': 64.087158203125,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 171,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 164.839111328125,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 1000.4158944042362,
#      'damageTakenOnTeamPercentage': 0.22487543003142002,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 11,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 3,
#      'gameLength': 844.222486342,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 609.1452773939408,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.1818181818181819,
#      'killAfterHiddenWithAlly': 5,
#      'killParticipation': 0.8125,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 11,
# ...
#      'laneMinionsFirst10Minutes': 32,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3091, 3124],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 0,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 6,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 54,
#      'skillshotsHit': 16,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 8,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 8,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1290346049709827,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 9835,
#     'champLevel': 12,
#     'championId': 67,
#     'championName': 'Vayne',
#     'championTransform': 0,
#     'commandPings': 2,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 16924,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 8598,
#     'goldSpent': 8150,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3184,
#     'item1': 3111,
#     'item2': 3091,
#     'item3': 2031,
#     'item4': 3124,
#     'item5': 0,
#     'item6': 0,
#     'itemsPurchased': 13,
#     'killingSprees': 1,
#     'kills': 2,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 238,
#     'magicDamageDealt': 3986,
#     'magicDamageDealtToChampions': 262,
#     'magicDamageTaken': 12515,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5001, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 167, 'var2': 80, 'var3': 0},
#         {'perk': 9104, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 133, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 563, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 320, 'var2': 4, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 22185,
#     'physicalDamageDealtToChampions': 4301,
#     'physicalDamageTaken': 5559,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 1439,
#     'pushPings': 0,
#     'puuid': '8eYOTbrevqzIP2Ac0SG2vFZQu5t7IxUf_CXMGe7gQSMWRD1y464NhsnEMOuz96vbZAF7xCTzHhBoyA',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': 'Cashiopaya',
#     'riotIdTagline': 'EUW',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 51,
#     'spell2Casts': 0,
#     'spell3Casts': 12,
#     'spell4Casts': 4,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 4,
#     'summoner2Id': 1,
#     'summonerId': 'H2FvOO19cKsZPJbUm0845NottoCKT-HmeD_60Sf-skAZGn4',
#     'summonerLevel': 270,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 6,
#     'timePlayed': 843,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 28611,
#     'totalDamageDealtToChampions': 4875,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 19564,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 2141,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 43,
#     'totalTimeCCDealt': 33,
#     'totalTimeSpentDead': 206,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2440,
#     'trueDamageDealtToChampions': 310,
#     'trueDamageTaken': 1489,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'PlayerScore0': 0,
#     'PlayerScore1': 0,
#     'PlayerScore10': 0,
#     'PlayerScore11': 0,
#     'PlayerScore2': 0,
#     'PlayerScore3': 0,
#     'PlayerScore4': 0,
#     'PlayerScore5': 0,
#     'PlayerScore6': 0,
#     'PlayerScore7': 0,
#     'PlayerScore8': 0,
#     'PlayerScore9': 0,
#     'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 9,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 3,
#     'challenges': {'12AssistStreakCount': 0,
#      'HealFromMapSources': 220.55354690551758,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 143,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 380.8648681640625,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 0,
#      'damagePerMinute': 563.611227113915,
#      'damageTakenOnTeamPercentage': 0.1489145841519395,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'effectiveHealAndShielding': 4672.185546875,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 12,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 1,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 3,
#      'gameLength': 844.222486342,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 625.2875574228683,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.75,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 3,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 2,
#      'landSkillShotsEarlyGame': 12,
#      'laneMinionsFirst10Minutes': 34,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6655],
#      'lostAnInhibitor': 0,
#      'maxKillDeficit': 0,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 8,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 21,
#      'skillshotsHit': 28,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 0,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 1,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 12,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 12,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.20987675164623437,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScorePerMinute': 0,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 0,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 10486,
#     'champLevel': 13,
#     'championId': 61,
#     'championName': 'Orianna',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 0,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 5325,
#     'dangerPings': 0,
#     'deaths': 4,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 8798,
#     'goldSpent': 6500,
#     'holdPings': 0,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6655,
#     'item1': 2031,
#     'item2': 1058,
#     'item3': 3020,
#     'item4': 1058,
#     'item5': 0,
#     'item6': 2052,
#     'itemsPurchased': 7,
#     'killingSprees': 1,
#     'kills': 3,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 236,
#     'magicDamageDealt': 25487,
#     'magicDamageDealtToChampions': 7895,
#     'magicDamageTaken': 7332,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 1,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 462, 'var2': 1482, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 90, 'var3': 0},
#         {'perk': 8210, 'var1': 4, 'var2': 0, 'var3': 0},
#         {'perk': 8236, 'var1': 24, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8009, 'var1': 1404, 'var2': 0, 'var3': 0},
#         {'perk': 8014, 'var1': 186, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 1753,
#     'physicalDamageDealtToChampions': 34,
#     'physicalDamageTaken': 2289,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6316,
#     'pushPings': 0,
#     'puuid': 'xeOSP_aJDyNWwNqNfQddm921jQXymaz19RI1cvR-ww3zHREhylgsV_BAldZDd5rWh_GtXFTNPXereA',
#     'quadraKills': 0,
#     'retreatPings': 0,
#     'riotIdGameName': 'Thomaz',
#     'riotIdTagline': '1996',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 49,
#     'spell2Casts': 33,
#     'spell3Casts': 57,
#     'spell4Casts': 4,
#     'subteamPlacement': 0,
#     'summoner1Casts': 2,
#     'summoner1Id': 4,
#     'summoner2Casts': 0,
#     'summoner2Id': 6,
#     'summonerId': 'GaLT-L6YHJJMEoawVhrpzSrHJcg6_v621I5Mo94wr97aIOtrwabuSksYyQ',
#     'summonerLevel': 194,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 11,
#     'timePlayed': 843,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 27241,
#     'totalDamageDealtToChampions': 7930,
#     'totalDamageShieldedOnTeammates': 4672,
#     'totalDamageTaken': 10317,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 218,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 39,
#     'totalTimeCCDealt': 80,
#     'totalTimeSpentDead': 84,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 696,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False}],
#   'platformId': 'EUW1',
#   'queueId': 450,
#   'teams': [{'bans': [],
#     'feats': {'EPIC_MONSTER_KILL': {'featState': 0},
#      'FIRST_BLOOD': {'featState': 0},
#      'FIRST_TURRET': {'featState': 0}},
#     'objectives': {'atakhan': {'first': False, 'kills': 0},
#      'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 34},
#      'dragon': {'first': False, 'kills': 0},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 4}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [],
#     'feats': {'EPIC_MONSTER_KILL': {'featState': 0},
#      'FIRST_BLOOD': {'featState': 0},
#      'FIRST_TURRET': {'featState': 0}},
#     'objectives': {'atakhan': {'first': False, 'kills': 0},
#      'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 17},
#      'dragon': {'first': False, 'kills': 0},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 0}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %%
url = f"https://europe.api.riotgames.com//lol/rso-match/v1/matches/jkoISeqpqCy5cr_NnNcuDjWKuXAQp5VmaoPxYwYRAwNuBHzivMXqMAzq61bNdKcutjzSyYTGBfr2XQ"
headers = {
        "X-Riot-Token": 'RGAPI-eb831182-3339-4d85-bb2a-f8ee34e3ac4c'
    }
requests.get(url,headers=headers).json()
# Out:
# {'status': {'message': 'Forbidden', 'status_code': 403}}
